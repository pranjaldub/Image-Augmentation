# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/input-key/training_frames_keypoints.csv
# /kaggle/input/input-key/test_frames_keypoints.csv
# /kaggle/input/input-key/training/training/Pilar_Montenegro_21.jpg
# /kaggle/input/input-key/training/training/Maggie_Smith_41.jpg
# /kaggle/input/input-key/training/training/Gabi_Zimmer_01.jpg
# /kaggle/input/input-key/training/training/Craig_David_20.jpg
# /kaggle/input/input-key/training/training/Carlo_Azeglio_Ciampi_00.jpg
# /kaggle/input/input-key/training/training/Celso_Lafer_22.jpg
# /kaggle/input/input-key/training/training/Agnes_Bruckner_42.jpg
# /kaggle/input/input-key/training/training/Luis_Fonsi_52.jpg
# /kaggle/input/input-key/training/training/Terje_Roed-Larsen_31.jpg
# /kaggle/input/input-key/training/training/Recep_Tayyip_Erdogan_02.jpg
# /kaggle/input/input-key/training/training/Bill_Bradley_52.jpg
# /kaggle/input/input-key/training/training/Jake_Gyllenhaal_41.jpg
# /kaggle/input/input-key/training/training/Adrian_Nastase_42.jpg
# /kaggle/input/input-key/training/training/Chris_Cooper_01.jpg
# /kaggle/input/input-key/training/training/Olene_Walker_01.jpg
# /kaggle/input/input-key/training/training/Maggie_Cheung_01.jpg
# /kaggle/input/input-key/training/training/Lucio_Stanca_31.jpg
# /kaggle/input/input-key/training/training/Jacqueline_Gold_30.jpg
# /kaggle/input/input-key/training/training/Takeo_Hiranuma_11.jpg
# /kaggle/input/input-key/training/training/Ahmed_Ahmed_02.jpg
# /kaggle/input/input-key/training/training/Warren_Buffett_51.jpg
# /kaggle/input/input-key/training/training/Charles_Bronson_10.jpg
# /kaggle/input/input-key/training/training/Richard_Branson_11.jpg
# /kaggle/input/input-key/training/training/Wesley_Clark_30.jpg
# /kaggle/input/input-key/training/training/Gabi_Zimmer_20.jpg
# /kaggle/input/input-key/training/training/Laura_Bush_52.jpg
# /kaggle/input/input-key/training/training/George_Karl_21.jpg
# /kaggle/input/input-key/training/training/Frank_Caliendo_31.jpg
# /kaggle/input/input-key/training/training/Marc_Racicot_52.jpg
# /kaggle/input/input-key/training/training/Kweisi_Mfume_50.jpg
# /kaggle/input/input-key/training/training/Robert_Altman_22.jpg
# /kaggle/input/input-key/training/training/Olene_Walker_40.jpg
# /kaggle/input/input-key/training/training/Elmar_Brok_01.jpg
# /kaggle/input/input-key/training/training/Elijah_Wood_10.jpg
# /kaggle/input/input-key/training/training/Conan_OBrien_00.jpg
# /kaggle/input/input-key/training/training/Nancy_Reagan_12.jpg
# /kaggle/input/input-key/training/training/Elsa_Zylberstein_41.jpg
# /kaggle/input/input-key/training/training/Loretta_Lynn_Harper_51.jpg
# /kaggle/input/input-key/training/training/Elton_John_10.jpg
# /kaggle/input/input-key/training/training/Norah_Jones_22.jpg
# /kaggle/input/input-key/training/training/Aleksander_Kwasniewski_11.jpg
# /kaggle/input/input-key/training/training/Ralph_Klein_02.jpg
# /kaggle/input/input-key/training/training/Poala_Suarez_42.jpg
# /kaggle/input/input-key/training/training/Benjamin_McKenzie_30.jpg
# /kaggle/input/input-key/training/training/Kit_Bond_32.jpg
# /kaggle/input/input-key/training/training/Christopher_Amolsch_51.jpg
# /kaggle/input/input-key/training/training/Linda_Dano_51.jpg
# /kaggle/input/input-key/training/training/Daniel_Rouse_21.jpg
# /kaggle/input/input-key/training/training/Lee_Baca_12.jpg
# /kaggle/input/input-key/training/training/Benjamin_McKenzie_40.jpg
# /kaggle/input/input-key/training/training/Ethan_Hawke_40.jpg
# /kaggle/input/input-key/training/training/Jane_Krakowski_42.jpg
# /kaggle/input/input-key/training/training/Robert_Altman_50.jpg
# /kaggle/input/input-key/training/training/Martin_Luther_King_III_32.jpg
# /kaggle/input/input-key/training/training/Laurence_Fishburne_22.jpg
# /kaggle/input/input-key/training/training/Edward_Burns_22.jpg
# /kaggle/input/input-key/training/training/Raza_Rabbani_21.jpg
# /kaggle/input/input-key/training/training/JK_Rowling_41.jpg
# /kaggle/input/input-key/training/training/Jan_Peter_Balkenende_00.jpg
# /kaggle/input/input-key/training/training/Olivia_Newton-John_41.jpg
# /kaggle/input/input-key/training/training/Marc_Racicot_41.jpg
# /kaggle/input/input-key/training/training/Priyanka_Chopra_42.jpg
# /kaggle/input/input-key/training/training/Laurence_Fishburne_42.jpg
# /kaggle/input/input-key/training/training/Teresa_Heinz_Kerry_11.jpg
# /kaggle/input/input-key/training/training/Yang_Jianli_12.jpg
# /kaggle/input/input-key/training/training/Princess_Stephanie_21.jpg
# /kaggle/input/input-key/training/training/Angela_Bassett_30.jpg
# /kaggle/input/input-key/training/training/Carlos_Iturgaitz_51.jpg
# /kaggle/input/input-key/training/training/Warren_Beatty_10.jpg
# /kaggle/input/input-key/training/training/Flavia_Pennetta_32.jpg
# /kaggle/input/input-key/training/training/Alejandro_Toledo_51.jpg
# /kaggle/input/input-key/training/training/Cristina_Fernandez_30.jpg
# /kaggle/input/input-key/training/training/Cameron_Diaz_20.jpg
# /kaggle/input/input-key/training/training/Chadha_Gurinder_21.jpg
# /kaggle/input/input-key/training/training/Cherie_Blair_31.jpg
# /kaggle/input/input-key/training/training/Lisa_Ling_22.jpg
# /kaggle/input/input-key/training/training/Martin_Sheen_00.jpg
# /kaggle/input/input-key/training/training/Piotr_Anderszewski_52.jpg
# /kaggle/input/input-key/training/training/Picabo_Street_02.jpg
# /kaggle/input/input-key/training/training/Jane_Rooney_01.jpg
# /kaggle/input/input-key/training/training/Mario_Kreutzberger_40.jpg
# /kaggle/input/input-key/training/training/Christopher_Reeve_20.jpg
# /kaggle/input/input-key/training/training/Kyle_Shewfelt_10.jpg
# /kaggle/input/input-key/training/training/Malcolm_Jamal_Warner_21.jpg
# /kaggle/input/input-key/training/training/Tom_Hanks_32.jpg
# /kaggle/input/input-key/training/training/Ricardo_Sanchez_40.jpg
# /kaggle/input/input-key/training/training/Laura_Bozzo_01.jpg
# /kaggle/input/input-key/training/training/Lino_Oviedo_30.jpg
# /kaggle/input/input-key/training/training/Tina_Brown_40.jpg
# /kaggle/input/input-key/training/training/Ricardo_Lopez_Murphy_30.jpg
# /kaggle/input/input-key/training/training/Kweisi_Mfume_11.jpg
# /kaggle/input/input-key/training/training/Alfredo_di_Stefano_22.jpg
# /kaggle/input/input-key/training/training/Luc_Montagnier_21.jpg
# /kaggle/input/input-key/training/training/David_Brent_01.jpg
# /kaggle/input/input-key/training/training/Mark_Foley_11.jpg
# /kaggle/input/input-key/training/training/Tom_Osborne_22.jpg
# /kaggle/input/input-key/training/training/Lindsey_Graham_11.jpg
# /kaggle/input/input-key/training/training/Andrea_Bocelli_31.jpg
# /kaggle/input/input-key/training/training/Marc_Anthony_20.jpg
# /kaggle/input/input-key/training/training/Marina_Silva_41.jpg
# /kaggle/input/input-key/training/training/Ben_Stein_42.jpg
# /kaggle/input/input-key/training/training/Carlos_Iturgaitz_21.jpg
# /kaggle/input/input-key/training/training/James_Wolfensohn_02.jpg
# /kaggle/input/input-key/training/training/Picabo_Street_41.jpg
# /kaggle/input/input-key/training/training/Louis_Van_Gaal_41.jpg
# /kaggle/input/input-key/training/training/Nicolas_Sarkozy_52.jpg
# /kaggle/input/input-key/training/training/Irene_Kahn_30.jpg
# /kaggle/input/input-key/training/training/Martin_Luther_King_III_31.jpg
# /kaggle/input/input-key/training/training/Prince_Harry_11.jpg
# /kaggle/input/input-key/training/training/James_McPherson_21.jpg
# /kaggle/input/input-key/training/training/Sasha_Cohen_52.jpg
# /kaggle/input/input-key/training/training/Jackie_Sherrill_22.jpg
# /kaggle/input/input-key/training/training/Rodrigo_Borja_51.jpg
# /kaggle/input/input-key/training/training/Saeed_Mortazavi_51.jpg
# /kaggle/input/input-key/training/training/Robbie_Coltrane_20.jpg
# /kaggle/input/input-key/training/training/T_Boone_Pickens_21.jpg
# /kaggle/input/input-key/training/training/Ricardo_Lopez_Murphy_41.jpg
# /kaggle/input/input-key/training/training/Irene_Kahn_42.jpg
# /kaggle/input/input-key/training/training/James_Cunningham_00.jpg
# /kaggle/input/input-key/training/training/Prince_Harry_42.jpg
# /kaggle/input/input-key/training/training/Hanan_Ashrawi_12.jpg
# /kaggle/input/input-key/training/training/Amelia_Vega_22.jpg
# /kaggle/input/input-key/training/training/David_Brent_32.jpg
# /kaggle/input/input-key/training/training/Alejandro_Toledo_50.jpg
# /kaggle/input/input-key/training/training/Nick_Reilly_40.jpg
# /kaggle/input/input-key/training/training/Frances_Fisher_20.jpg
# /kaggle/input/input-key/training/training/Andrea_Bocelli_32.jpg
# /kaggle/input/input-key/training/training/Andrea_Bocelli_22.jpg
# /kaggle/input/input-key/training/training/Franz_Fischler_00.jpg
# /kaggle/input/input-key/training/training/Alma_Powell_12.jpg
# /kaggle/input/input-key/training/training/Natalia_Vodonova_21.jpg
# /kaggle/input/input-key/training/training/Nicolas_Sarkozy_51.jpg
# /kaggle/input/input-key/training/training/Elmar_Brok_32.jpg
# /kaggle/input/input-key/training/training/Natalia_Vodonova_12.jpg
# /kaggle/input/input-key/training/training/Peter_Goldmark_52.jpg
# /kaggle/input/input-key/training/training/Ali_Abbas_32.jpg
# /kaggle/input/input-key/training/training/Martin_Sheen_52.jpg
# /kaggle/input/input-key/training/training/Mary_Robinson_11.jpg
# /kaggle/input/input-key/training/training/Edward_Burns_51.jpg
# /kaggle/input/input-key/training/training/Leszek_Miller_01.jpg
# /kaggle/input/input-key/training/training/Warren_Buffett_01.jpg
# /kaggle/input/input-key/training/training/Ralph_Klein_01.jpg
# /kaggle/input/input-key/training/training/Mariana_Ohata_02.jpg
# /kaggle/input/input-key/training/training/Andy_Roddick_21.jpg
# /kaggle/input/input-key/training/training/Adam_Sandler_00.jpg
# /kaggle/input/input-key/training/training/Connie_Chung_22.jpg
# /kaggle/input/input-key/training/training/Eunice_Barber_00.jpg
# /kaggle/input/input-key/training/training/Thomas_Ferguson_10.jpg
# /kaggle/input/input-key/training/training/Mack_Brown_01.jpg
# /kaggle/input/input-key/training/training/Timothy_Goebel_52.jpg
# /kaggle/input/input-key/training/training/Manuel_Pellegrini_11.jpg
# /kaggle/input/input-key/training/training/Maria_Soledad_Alvear_Valenzuela_12.jpg
# /kaggle/input/input-key/training/training/Chris_Matthews_12.jpg
# /kaggle/input/input-key/training/training/Ali_Abbas_20.jpg
# /kaggle/input/input-key/training/training/James_Wolfensohn_52.jpg
# /kaggle/input/input-key/training/training/Lino_Oviedo_32.jpg
# /kaggle/input/input-key/training/training/Chris_Cooper_31.jpg
# /kaggle/input/input-key/training/training/Nicolas_Eyzaguirre_01.jpg
# /kaggle/input/input-key/training/training/Ernest_Hollings_21.jpg
# /kaggle/input/input-key/training/training/Rodrigo_Borja_50.jpg
# /kaggle/input/input-key/training/training/Nancy_Reagan_40.jpg
# /kaggle/input/input-key/training/training/Bianca_Jagger_20.jpg
# /kaggle/input/input-key/training/training/Dai_Bachtiar_50.jpg
# /kaggle/input/input-key/training/training/Wes_Craven_02.jpg
# /kaggle/input/input-key/training/training/Timothy_Goebel_51.jpg
# /kaggle/input/input-key/training/training/Beyonce_Knowles_50.jpg
# /kaggle/input/input-key/training/training/Chris_Cooper_32.jpg
# /kaggle/input/input-key/training/training/Paul_Reiser_32.jpg
# /kaggle/input/input-key/training/training/Lucio_Stanca_22.jpg
# /kaggle/input/input-key/training/training/Charlotte_Rampling_40.jpg
# /kaggle/input/input-key/training/training/Ed_Smart_32.jpg
# /kaggle/input/input-key/training/training/Marc_Shaiman_31.jpg
# /kaggle/input/input-key/training/training/Chita_Rivera_02.jpg
# /kaggle/input/input-key/training/training/Peter_Goldmark_51.jpg
# /kaggle/input/input-key/training/training/Terje_Roed-Larsen_02.jpg
# /kaggle/input/input-key/training/training/Christopher_Amolsch_20.jpg
# /kaggle/input/input-key/training/training/Daniel_Radcliffe_21.jpg
# /kaggle/input/input-key/training/training/Bill_Bradley_50.jpg
# /kaggle/input/input-key/training/training/Mack_Brown_50.jpg
# /kaggle/input/input-key/training/training/Paul_Reiser_00.jpg
# /kaggle/input/input-key/training/training/Albert_Brooks_02.jpg
# /kaggle/input/input-key/training/training/Thomas_Ferguson_50.jpg
# /kaggle/input/input-key/training/training/Kristy_Curry_30.jpg
# /kaggle/input/input-key/training/training/Ben_Stein_30.jpg
# /kaggle/input/input-key/training/training/Otto_Reich_42.jpg
# /kaggle/input/input-key/training/training/Biljana_Plavsic_01.jpg
# /kaggle/input/input-key/training/training/Ralph_Klein_31.jpg
# /kaggle/input/input-key/training/training/Katja_Riemann_12.jpg
# /kaggle/input/input-key/training/training/Marieta_Chrousala_40.jpg
# /kaggle/input/input-key/training/training/Jackie_Sherrill_20.jpg
# /kaggle/input/input-key/training/training/Chuck_Woolery_42.jpg
# /kaggle/input/input-key/training/training/Hassan_Nasrallah_30.jpg
# /kaggle/input/input-key/training/training/Connie_Chung_51.jpg
# /kaggle/input/input-key/training/training/Agbani_Darego_22.jpg
# /kaggle/input/input-key/training/training/Lucio_Stanca_41.jpg
# /kaggle/input/input-key/training/training/Elsa_Zylberstein_00.jpg
# /kaggle/input/input-key/training/training/Robbie_Coltrane_02.jpg
# /kaggle/input/input-key/training/training/Martin_Sheen_31.jpg
# /kaggle/input/input-key/training/training/Ricardo_Sanchez_32.jpg
# /kaggle/input/input-key/training/training/Paul_Otellini_21.jpg
# /kaggle/input/input-key/training/training/Tessa_Jowell_52.jpg
# /kaggle/input/input-key/training/training/Celso_Amorim_42.jpg
# /kaggle/input/input-key/training/training/Angelo_Reyes_20.jpg
# /kaggle/input/input-key/training/training/Marc_Racicot_01.jpg
# /kaggle/input/input-key/training/training/Dai_Bachtiar_02.jpg
# /kaggle/input/input-key/training/training/Lee_Baca_41.jpg
# /kaggle/input/input-key/training/training/Gary_Coleman_52.jpg
# /kaggle/input/input-key/training/training/Valerie_Harper_40.jpg
# /kaggle/input/input-key/training/training/Leticia_Van_de_Putte_02.jpg
# /kaggle/input/input-key/training/training/Mary_Landrieu_31.jpg
# /kaggle/input/input-key/training/training/Olivia_Newton-John_10.jpg
# /kaggle/input/input-key/training/training/Linda_Sanchez_20.jpg
# /kaggle/input/input-key/training/training/Hassan_Nasrallah_50.jpg
# /kaggle/input/input-key/training/training/Yang_Jianli_31.jpg
# /kaggle/input/input-key/training/training/Charlotte_Rampling_42.jpg
# /kaggle/input/input-key/training/training/Ed_Rendell_51.jpg
# /kaggle/input/input-key/training/training/Fernando_Sanz_51.jpg
# /kaggle/input/input-key/training/training/Olene_Walker_32.jpg
# /kaggle/input/input-key/training/training/Otto_Reich_31.jpg
# /kaggle/input/input-key/training/training/Piotr_Anderszewski_20.jpg
# /kaggle/input/input-key/training/training/Angela_Bassett_32.jpg
# /kaggle/input/input-key/training/training/Martin_Sheen_01.jpg
# /kaggle/input/input-key/training/training/Christopher_Walken_51.jpg
# /kaggle/input/input-key/training/training/Lucia_Kenny_Anthony_01.jpg
# /kaggle/input/input-key/training/training/Celso_Amorim_12.jpg
# /kaggle/input/input-key/training/training/Luis_Ernesto_Derbez_Bautista_12.jpg
# /kaggle/input/input-key/training/training/Picabo_Street_21.jpg
# /kaggle/input/input-key/training/training/Wayne_Newton_10.jpg
# /kaggle/input/input-key/training/training/Andy_Roddick_22.jpg
# /kaggle/input/input-key/training/training/Richard_Branson_52.jpg
# /kaggle/input/input-key/training/training/Mary_Landrieu_00.jpg
# /kaggle/input/input-key/training/training/Terje_Roed-Larsen_01.jpg
# /kaggle/input/input-key/training/training/Tom_Harkin_40.jpg
# /kaggle/input/input-key/training/training/Irene_Kahn_02.jpg
# /kaggle/input/input-key/training/training/Terje_Roed-Larsen_32.jpg
# /kaggle/input/input-key/training/training/Takeo_Hiranuma_31.jpg
# /kaggle/input/input-key/training/training/Abdullah_Gul_31.jpg
# /kaggle/input/input-key/training/training/Teresa_Heinz_Kerry_10.jpg
# /kaggle/input/input-key/training/training/Ridley_Scott_30.jpg
# /kaggle/input/input-key/training/training/Lee_Baca_00.jpg
# /kaggle/input/input-key/training/training/Paul_Reiser_22.jpg
# /kaggle/input/input-key/training/training/Robert_Altman_21.jpg
# /kaggle/input/input-key/training/training/Kathryn_Morris_22.jpg
# /kaggle/input/input-key/training/training/Gary_Coleman_42.jpg
# /kaggle/input/input-key/training/training/Tom_Harkin_02.jpg
# /kaggle/input/input-key/training/training/Conan_OBrien_52.jpg
# /kaggle/input/input-key/training/training/Ernie_Grunfeld_31.jpg
# /kaggle/input/input-key/training/training/Fernando_Sanz_31.jpg
# /kaggle/input/input-key/training/training/Zhong_Nanshan_11.jpg
# /kaggle/input/input-key/training/training/Adam_Sandler_11.jpg
# /kaggle/input/input-key/training/training/Eunice_Barber_50.jpg
# /kaggle/input/input-key/training/training/Chuck_Woolery_20.jpg
# /kaggle/input/input-key/training/training/Keith_Olbermann_52.jpg
# /kaggle/input/input-key/training/training/Kirk_Ferentz_50.jpg
# /kaggle/input/input-key/training/training/Zhang_Ziyi_11.jpg
# /kaggle/input/input-key/training/training/Barry_Alvarez_10.jpg
# /kaggle/input/input-key/training/training/Harrison_Ford_20.jpg
# /kaggle/input/input-key/training/training/James_Hoffa_21.jpg
# /kaggle/input/input-key/training/training/Lester_Holt_41.jpg
# /kaggle/input/input-key/training/training/Colin_Powell_51.jpg
# /kaggle/input/input-key/training/training/Wes_Craven_00.jpg
# /kaggle/input/input-key/training/training/Barbara_Walters_40.jpg
# /kaggle/input/input-key/training/training/Rocco_Buttiglione_41.jpg
# /kaggle/input/input-key/training/training/Alicia_Silverstone_22.jpg
# /kaggle/input/input-key/training/training/Craig_David_30.jpg
# /kaggle/input/input-key/training/training/Florecita_Cobian_10.jpg
# /kaggle/input/input-key/training/training/Lucia_Kenny_Anthony_10.jpg
# /kaggle/input/input-key/training/training/Marina_Silva_40.jpg
# /kaggle/input/input-key/training/training/Linda_Dano_32.jpg
# /kaggle/input/input-key/training/training/Christopher_Walken_01.jpg
# /kaggle/input/input-key/training/training/Lucia_Kenny_Anthony_11.jpg
# /kaggle/input/input-key/training/training/Frank_Beamer_31.jpg
# /kaggle/input/input-key/training/training/Takeo_Hiranuma_01.jpg
# /kaggle/input/input-key/training/training/Angelo_Reyes_50.jpg
# /kaggle/input/input-key/training/training/Jack_Welch_52.jpg
# /kaggle/input/input-key/training/training/Norman_Mineta_51.jpg
# /kaggle/input/input-key/training/training/Barry_Alvarez_21.jpg
# /kaggle/input/input-key/training/training/Mariana_Ohata_32.jpg
# /kaggle/input/input-key/training/training/Valerie_Harper_00.jpg
# /kaggle/input/input-key/training/training/Francis_Collins_10.jpg
# /kaggle/input/input-key/training/training/Andy_Roddick_52.jpg
# /kaggle/input/input-key/training/training/Emmy_Rossum_20.jpg
# /kaggle/input/input-key/training/training/Frank_Caliendo_50.jpg
# /kaggle/input/input-key/training/training/Ed_Rendell_52.jpg
# /kaggle/input/input-key/training/training/Cherie_Blair_42.jpg
# /kaggle/input/input-key/training/training/Clint_Howard_30.jpg
# /kaggle/input/input-key/training/training/Louis_Van_Gaal_01.jpg
# /kaggle/input/input-key/training/training/Ellen_DeGeneres_42.jpg
# /kaggle/input/input-key/training/training/Reese_Witherspoon_42.jpg
# /kaggle/input/input-key/training/training/Vicente_Fox_30.jpg
# /kaggle/input/input-key/training/training/Isabella_Rossellini_22.jpg
# /kaggle/input/input-key/training/training/Elton_John_32.jpg
# /kaggle/input/input-key/training/training/Emma_Thompson_20.jpg
# /kaggle/input/input-key/training/training/Norman_Mineta_32.jpg
# /kaggle/input/input-key/training/training/Andy_Roddick_41.jpg
# /kaggle/input/input-key/training/training/Prince_Harry_12.jpg
# /kaggle/input/input-key/training/training/Linda_Sanchez_22.jpg
# /kaggle/input/input-key/training/training/Clay_Aiken_02.jpg
# /kaggle/input/input-key/training/training/Carlos_Queiroz_00.jpg
# /kaggle/input/input-key/training/training/Daniel_Radcliffe_22.jpg
# /kaggle/input/input-key/training/training/Tessa_Jowell_50.jpg
# /kaggle/input/input-key/training/training/Daniell_Sunjata_42.jpg
# /kaggle/input/input-key/training/training/Tim_Pawlenty_31.jpg
# /kaggle/input/input-key/training/training/Tim_Pawlenty_41.jpg
# /kaggle/input/input-key/training/training/Lindsey_Graham_21.jpg
# /kaggle/input/input-key/training/training/Charles_Bronson_52.jpg
# /kaggle/input/input-key/training/training/Penelope_Ann_Miller_20.jpg
# /kaggle/input/input-key/training/training/William_Delahunt_20.jpg
# /kaggle/input/input-key/training/training/Barry_Alvarez_11.jpg
# /kaggle/input/input-key/training/training/Elijah_Wood_02.jpg
# /kaggle/input/input-key/training/training/James_Carville_10.jpg
# /kaggle/input/input-key/training/training/Luc_Montagnier_52.jpg
# /kaggle/input/input-key/training/training/Colin_Powell_50.jpg
# /kaggle/input/input-key/training/training/Ernesto_Zedillo_42.jpg
# /kaggle/input/input-key/training/training/Kit_Bond_11.jpg
# /kaggle/input/input-key/training/training/Charlotte_Casiraghi_10.jpg
# /kaggle/input/input-key/training/training/Cameron_Diaz_51.jpg
# /kaggle/input/input-key/training/training/Cherie_Blair_22.jpg
# /kaggle/input/input-key/training/training/Colin_Powell_10.jpg
# /kaggle/input/input-key/training/training/Andy_Rooney_51.jpg
# /kaggle/input/input-key/training/training/Ernie_Grunfeld_41.jpg
# /kaggle/input/input-key/training/training/Orlando_Bloom_02.jpg
# /kaggle/input/input-key/training/training/Emmy_Rossum_22.jpg
# /kaggle/input/input-key/training/training/Thomas_Ferguson_00.jpg
# /kaggle/input/input-key/training/training/Penelope_Ann_Miller_02.jpg
# /kaggle/input/input-key/training/training/Charlotte_Rampling_31.jpg
# /kaggle/input/input-key/training/training/Andrea_Bocelli_20.jpg
# /kaggle/input/input-key/training/training/Dan_Ackroyd_32.jpg
# /kaggle/input/input-key/training/training/Katharine_Hepburn_41.jpg
# /kaggle/input/input-key/training/training/Angel_Lockward_40.jpg
# /kaggle/input/input-key/training/training/Marisa_Tomei_10.jpg
# /kaggle/input/input-key/training/training/Jackie_Sherrill_52.jpg
# /kaggle/input/input-key/training/training/Carlos_Ghosn_40.jpg
# /kaggle/input/input-key/training/training/Tom_Coughlin_51.jpg
# /kaggle/input/input-key/training/training/Emma_Nicholson_11.jpg
# /kaggle/input/input-key/training/training/Jan_Peter_Balkenende_11.jpg
# /kaggle/input/input-key/training/training/Amelia_Vega_12.jpg
# /kaggle/input/input-key/training/training/Rick_Bragg_31.jpg
# /kaggle/input/input-key/training/training/Kate_Winslet_52.jpg
# /kaggle/input/input-key/training/training/Nick_Reilly_10.jpg
# /kaggle/input/input-key/training/training/Adrian_Nastase_41.jpg
# /kaggle/input/input-key/training/training/Ernie_Grunfeld_32.jpg
# /kaggle/input/input-key/training/training/Colin_Powell_42.jpg
# /kaggle/input/input-key/training/training/Andy_Rooney_22.jpg
# /kaggle/input/input-key/training/training/Edward_Norton_40.jpg
# /kaggle/input/input-key/training/training/Philippe_Gagnon_22.jpg
# /kaggle/input/input-key/training/training/Norman_Mineta_01.jpg
# /kaggle/input/input-key/training/training/Lisa_Ling_01.jpg
# /kaggle/input/input-key/training/training/Fernando_Henrique_Cardoso_20.jpg
# /kaggle/input/input-key/training/training/Marieta_Chrousala_11.jpg
# /kaggle/input/input-key/training/training/Dave_Campo_21.jpg
# /kaggle/input/input-key/training/training/Fernando_Henrique_Cardoso_32.jpg
# /kaggle/input/input-key/training/training/Philippe_Noiret_31.jpg
# /kaggle/input/input-key/training/training/Yang_Jianli_01.jpg
# /kaggle/input/input-key/training/training/Yuri_Fedotov_42.jpg
# /kaggle/input/input-key/training/training/Louis_Van_Gaal_10.jpg
# /kaggle/input/input-key/training/training/Linda_Sanchez_00.jpg
# /kaggle/input/input-key/training/training/Emma_Thompson_22.jpg
# /kaggle/input/input-key/training/training/Maggie_Cheung_02.jpg
# /kaggle/input/input-key/training/training/Rocco_Buttiglione_10.jpg
# /kaggle/input/input-key/training/training/William_Donaldson_52.jpg
# /kaggle/input/input-key/training/training/Kit_Bond_20.jpg
# /kaggle/input/input-key/training/training/Aishwarya_Rai_41.jpg
# /kaggle/input/input-key/training/training/Raja_Zafar-ul-Haq_32.jpg
# /kaggle/input/input-key/training/training/Margaret_Thatcher_42.jpg
# /kaggle/input/input-key/training/training/Frank_Keating_50.jpg
# /kaggle/input/input-key/training/training/JK_Rowling_20.jpg
# /kaggle/input/input-key/training/training/Aishwarya_Rai_01.jpg
# /kaggle/input/input-key/training/training/Louis_Van_Gaal_40.jpg
# /kaggle/input/input-key/training/training/Matt_LeBlanc_31.jpg
# /kaggle/input/input-key/training/training/Lucio_Stanca_20.jpg
# /kaggle/input/input-key/training/training/Eduardo_Duhalde_31.jpg
# /kaggle/input/input-key/training/training/Darrell_Issa_20.jpg
# /kaggle/input/input-key/training/training/Carlos_Iturgaitz_20.jpg
# /kaggle/input/input-key/training/training/Nanni_Moretti_21.jpg
# /kaggle/input/input-key/training/training/Nancy_Kerrigan_22.jpg
# /kaggle/input/input-key/training/training/William_McDonough_40.jpg
# /kaggle/input/input-key/training/training/Ali_Abbas_21.jpg
# /kaggle/input/input-key/training/training/Barbara_Bodine_00.jpg
# /kaggle/input/input-key/training/training/Priyanka_Chopra_40.jpg
# /kaggle/input/input-key/training/training/Christopher_Amolsch_42.jpg
# /kaggle/input/input-key/training/training/Carlos_Ghosn_10.jpg
# /kaggle/input/input-key/training/training/Norman_Mineta_52.jpg
# /kaggle/input/input-key/training/training/Warren_Buffett_30.jpg
# /kaggle/input/input-key/training/training/Chris_Cirino_22.jpg
# /kaggle/input/input-key/training/training/Tim_Pawlenty_40.jpg
# /kaggle/input/input-key/training/training/Isabelle_Huppert_40.jpg
# /kaggle/input/input-key/training/training/Hanan_Ashrawi_40.jpg
# /kaggle/input/input-key/training/training/Queen_Rania_31.jpg
# /kaggle/input/input-key/training/training/Chris_Cirino_52.jpg
# /kaggle/input/input-key/training/training/Sarah_Wynter_51.jpg
# /kaggle/input/input-key/training/training/Fernando_Henrique_Cardoso_31.jpg
# /kaggle/input/input-key/training/training/Emilio_Botin_22.jpg
# /kaggle/input/input-key/training/training/Christopher_Walken_42.jpg
# /kaggle/input/input-key/training/training/Tom_Hanks_31.jpg
# /kaggle/input/input-key/training/training/Alejandro_Toledo_10.jpg
# /kaggle/input/input-key/training/training/Alma_Powell_50.jpg
# /kaggle/input/input-key/training/training/Elizabeth_Dole_00.jpg
# /kaggle/input/input-key/training/training/Natalia_Vodonova_01.jpg
# /kaggle/input/input-key/training/training/Kweisi_Mfume_42.jpg
# /kaggle/input/input-key/training/training/Carlos_Queiroz_51.jpg
# /kaggle/input/input-key/training/training/Kathryn_Morris_42.jpg
# /kaggle/input/input-key/training/training/Laura_Bush_42.jpg
# /kaggle/input/input-key/training/training/Lucia_Kenny_Anthony_40.jpg
# /kaggle/input/input-key/training/training/Chris_Noth_00.jpg
# /kaggle/input/input-key/training/training/Emma_Nicholson_31.jpg
# /kaggle/input/input-key/training/training/Elijah_Wood_12.jpg
# /kaggle/input/input-key/training/training/Adam_Sandler_41.jpg
# /kaggle/input/input-key/training/training/Warren_Buffett_52.jpg
# /kaggle/input/input-key/training/training/Keith_Tyson_21.jpg
# /kaggle/input/input-key/training/training/Manuel_Pellegrini_21.jpg
# /kaggle/input/input-key/training/training/Wes_Craven_31.jpg
# /kaggle/input/input-key/training/training/Harrison_Ford_11.jpg
# /kaggle/input/input-key/training/training/Bill_Bradley_32.jpg
# /kaggle/input/input-key/training/training/Linda_Dano_31.jpg
# /kaggle/input/input-key/training/training/Gary_Coleman_51.jpg
# /kaggle/input/input-key/training/training/Luis_Fonsi_21.jpg
# /kaggle/input/input-key/training/training/Carlos_Ghosn_22.jpg
# /kaggle/input/input-key/training/training/Chuck_Woolery_12.jpg
# /kaggle/input/input-key/training/training/Sarah_Wynter_52.jpg
# /kaggle/input/input-key/training/training/Franz_Fischler_41.jpg
# /kaggle/input/input-key/training/training/Kristin_Scott_41.jpg
# /kaggle/input/input-key/training/training/Peter_Medgyessy_12.jpg
# /kaggle/input/input-key/training/training/Kathryn_Morris_41.jpg
# /kaggle/input/input-key/training/training/Dai_Bachtiar_51.jpg
# /kaggle/input/input-key/training/training/Dan_Ackroyd_30.jpg
# /kaggle/input/input-key/training/training/Kieran_Culkin_20.jpg
# /kaggle/input/input-key/training/training/Elton_John_40.jpg
# /kaggle/input/input-key/training/training/Cristina_Fernandez_32.jpg
# /kaggle/input/input-key/training/training/Charlotte_Casiraghi_22.jpg
# /kaggle/input/input-key/training/training/Carrie-Anne_Moss_51.jpg
# /kaggle/input/input-key/training/training/Richard_Branson_10.jpg
# /kaggle/input/input-key/training/training/Adrian_Nastase_52.jpg
# /kaggle/input/input-key/training/training/Tina_Brown_52.jpg
# /kaggle/input/input-key/training/training/Christopher_Reeve_10.jpg
# /kaggle/input/input-key/training/training/Whoopi_Goldberg_52.jpg
# /kaggle/input/input-key/training/training/Kemal_Dervis_10.jpg
# /kaggle/input/input-key/training/training/Jack_Welch_10.jpg
# /kaggle/input/input-key/training/training/Jane_Pauley_31.jpg
# /kaggle/input/input-key/training/training/Hassan_Nasrallah_40.jpg
# /kaggle/input/input-key/training/training/Leticia_Van_de_Putte_00.jpg
# /kaggle/input/input-key/training/training/Lino_Oviedo_02.jpg
# /kaggle/input/input-key/training/training/Teresa_Heinz_Kerry_01.jpg
# /kaggle/input/input-key/training/training/Manuel_Pellegrini_22.jpg
# /kaggle/input/input-key/training/training/Flavia_Pennetta_52.jpg
# /kaggle/input/input-key/training/training/Robert_Altman_51.jpg
# /kaggle/input/input-key/training/training/Liu_Ye_51.jpg
# /kaggle/input/input-key/training/training/Agnes_Bruckner_00.jpg
# /kaggle/input/input-key/training/training/Prince_Harry_21.jpg
# /kaggle/input/input-key/training/training/Vicente_Fox_11.jpg
# /kaggle/input/input-key/training/training/GL_Peiris_32.jpg
# /kaggle/input/input-key/training/training/Isabella_Rossellini_10.jpg
# /kaggle/input/input-key/training/training/Benjamin_McKenzie_52.jpg
# /kaggle/input/input-key/training/training/Emma_Nicholson_20.jpg
# /kaggle/input/input-key/training/training/Alvaro_Silva_Calderon_30.jpg
# /kaggle/input/input-key/training/training/Kristin_Scott_42.jpg
# /kaggle/input/input-key/training/training/Gene_Hackman_31.jpg
# /kaggle/input/input-key/training/training/Wayne_Gretzky_21.jpg
# /kaggle/input/input-key/training/training/Raja_Zafar-ul-Haq_11.jpg
# /kaggle/input/input-key/training/training/Zhang_Ziyi_22.jpg
# /kaggle/input/input-key/training/training/Baburam_Bhattari_01.jpg
# /kaggle/input/input-key/training/training/Kirk_Ferentz_00.jpg
# /kaggle/input/input-key/training/training/Itzhak_Perlman_30.jpg
# /kaggle/input/input-key/training/training/Ben_Stein_52.jpg
# /kaggle/input/input-key/training/training/Ed_Rendell_01.jpg
# /kaggle/input/input-key/training/training/Edward_Norton_31.jpg
# /kaggle/input/input-key/training/training/Celso_Amorim_10.jpg
# /kaggle/input/input-key/training/training/Aishwarya_Rai_10.jpg
# /kaggle/input/input-key/training/training/Wes_Craven_32.jpg
# /kaggle/input/input-key/training/training/Kate_Capshaw_10.jpg
# /kaggle/input/input-key/training/training/Keith_Olbermann_11.jpg
# /kaggle/input/input-key/training/training/Massoud_Barzani_42.jpg
# /kaggle/input/input-key/training/training/Florecita_Cobian_22.jpg
# /kaggle/input/input-key/training/training/Kate_Winslet_01.jpg
# /kaggle/input/input-key/training/training/Hanan_Ashrawi_20.jpg
# /kaggle/input/input-key/training/training/Jane_Krakowski_50.jpg
# /kaggle/input/input-key/training/training/Ben_Stein_10.jpg
# /kaggle/input/input-key/training/training/Cristina_Fernandez_31.jpg
# /kaggle/input/input-key/training/training/Itzhak_Perlman_12.jpg
# /kaggle/input/input-key/training/training/Peter_Medgyessy_51.jpg
# /kaggle/input/input-key/training/training/Lino_Oviedo_51.jpg
# /kaggle/input/input-key/training/training/Chuck_Hagel_51.jpg
# /kaggle/input/input-key/training/training/Philippe_Noiret_11.jpg
# /kaggle/input/input-key/training/training/Benjamin_Netanyahu_01.jpg
# /kaggle/input/input-key/training/training/Leszek_Miller_30.jpg
# /kaggle/input/input-key/training/training/Zhong_Nanshan_10.jpg
# /kaggle/input/input-key/training/training/Mahathir_Mohamad_00.jpg
# /kaggle/input/input-key/training/training/Nancy_Kerrigan_32.jpg
# /kaggle/input/input-key/training/training/James_Hoffa_11.jpg
# /kaggle/input/input-key/training/training/Richard_Lugar_20.jpg
# /kaggle/input/input-key/training/training/Elsa_Zylberstein_12.jpg
# /kaggle/input/input-key/training/training/Benedita_da_Silva_12.jpg
# /kaggle/input/input-key/training/training/Clint_Howard_00.jpg
# /kaggle/input/input-key/training/training/Warren_Buffett_42.jpg
# /kaggle/input/input-key/training/training/Lester_Holt_42.jpg
# /kaggle/input/input-key/training/training/Benedita_da_Silva_50.jpg
# /kaggle/input/input-key/training/training/Ben_Stein_32.jpg
# /kaggle/input/input-key/training/training/Eric_Benet_11.jpg
# /kaggle/input/input-key/training/training/William_Donaldson_50.jpg
# /kaggle/input/input-key/training/training/Ernesto_Zedillo_10.jpg
# /kaggle/input/input-key/training/training/Christine_Ebersole_22.jpg
# /kaggle/input/input-key/training/training/Tim_Howard_01.jpg
# /kaggle/input/input-key/training/training/Lucia_Kenny_Anthony_00.jpg
# /kaggle/input/input-key/training/training/Craig_David_52.jpg
# /kaggle/input/input-key/training/training/Leszek_Miller_32.jpg
# /kaggle/input/input-key/training/training/Mary_Robinson_41.jpg
# /kaggle/input/input-key/training/training/Benjamin_Netanyahu_00.jpg
# /kaggle/input/input-key/training/training/Eric_Benet_30.jpg
# /kaggle/input/input-key/training/training/Amelia_Vega_21.jpg
# /kaggle/input/input-key/training/training/Flavia_Pennetta_51.jpg
# /kaggle/input/input-key/training/training/Ralph_Klein_11.jpg
# /kaggle/input/input-key/training/training/Mary_Robinson_20.jpg
# /kaggle/input/input-key/training/training/Timothy_Goebel_50.jpg
# /kaggle/input/input-key/training/training/Priyanka_Chopra_41.jpg
# /kaggle/input/input-key/training/training/Nancy_Reagan_30.jpg
# /kaggle/input/input-key/training/training/T_Boone_Pickens_20.jpg
# /kaggle/input/input-key/training/training/Gary_Coleman_30.jpg
# /kaggle/input/input-key/training/training/Fernando_Henrique_Cardoso_30.jpg
# /kaggle/input/input-key/training/training/Olene_Walker_12.jpg
# /kaggle/input/input-key/training/training/Agnes_Bruckner_40.jpg
# /kaggle/input/input-key/training/training/Ahmed_Ahmed_10.jpg
# /kaggle/input/input-key/training/training/Christopher_Amolsch_40.jpg
# /kaggle/input/input-key/training/training/Eunice_Barber_02.jpg
# /kaggle/input/input-key/training/training/Eliane_Karp_31.jpg
# /kaggle/input/input-key/training/training/Queen_Rania_51.jpg
# /kaggle/input/input-key/training/training/Clive_Lloyd_41.jpg
# /kaggle/input/input-key/training/training/Edie_Falco_22.jpg
# /kaggle/input/input-key/training/training/Baburam_Bhattari_22.jpg
# /kaggle/input/input-key/training/training/Recep_Tayyip_Erdogan_40.jpg
# /kaggle/input/input-key/training/training/Mahathir_Mohamad_31.jpg
# /kaggle/input/input-key/training/training/Sally_Ride_01.jpg
# /kaggle/input/input-key/training/training/Kristin_Scott_10.jpg
# /kaggle/input/input-key/training/training/Cherie_Blair_41.jpg
# /kaggle/input/input-key/training/training/David_Caruso_12.jpg
# /kaggle/input/input-key/training/training/Tom_Hanks_30.jpg
# /kaggle/input/input-key/training/training/Tom_Ridge_30.jpg
# /kaggle/input/input-key/training/training/Gary_Condit_02.jpg
# /kaggle/input/input-key/training/training/Elaine_Chao_21.jpg
# /kaggle/input/input-key/training/training/Linda_Dano_30.jpg
# /kaggle/input/input-key/training/training/Mario_Kreutzberger_21.jpg
# /kaggle/input/input-key/training/training/Fernando_Sanz_32.jpg
# /kaggle/input/input-key/training/training/Orlando_Bloom_32.jpg
# /kaggle/input/input-key/training/training/Laurence_Fishburne_41.jpg
# /kaggle/input/input-key/training/training/GL_Peiris_00.jpg
# /kaggle/input/input-key/training/training/Clark_Randt_50.jpg
# /kaggle/input/input-key/training/training/Leszek_Miller_02.jpg
# /kaggle/input/input-key/training/training/Alexandra_Pelosi_00.jpg
# /kaggle/input/input-key/training/training/Andy_Roddick_51.jpg
# /kaggle/input/input-key/training/training/Margaret_Thatcher_40.jpg
# /kaggle/input/input-key/training/training/Bill_Frist_12.jpg
# /kaggle/input/input-key/training/training/Philippe_Gagnon_31.jpg
# /kaggle/input/input-key/training/training/Chris_Cirino_51.jpg
# /kaggle/input/input-key/training/training/Franz_Fischler_50.jpg
# /kaggle/input/input-key/training/training/Alicia_Silverstone_01.jpg
# /kaggle/input/input-key/training/training/Liu_Ye_22.jpg
# /kaggle/input/input-key/training/training/Connie_Chung_41.jpg
# /kaggle/input/input-key/training/training/Clint_Howard_02.jpg
# /kaggle/input/input-key/training/training/James_McPherson_12.jpg
# /kaggle/input/input-key/training/training/Frances_Fisher_31.jpg
# /kaggle/input/input-key/training/training/Marc_Racicot_22.jpg
# /kaggle/input/input-key/training/training/Tessa_Jowell_02.jpg
# /kaggle/input/input-key/training/training/Elijah_Wood_01.jpg
# /kaggle/input/input-key/training/training/Ricardo_Lopez_Murphy_40.jpg
# /kaggle/input/input-key/training/training/Malcolm_Jamal_Warner_22.jpg
# /kaggle/input/input-key/training/training/Geoffrey_Rush_02.jpg
# /kaggle/input/input-key/training/training/Harrison_Ford_10.jpg
# /kaggle/input/input-key/training/training/Louis_Van_Gaal_11.jpg
# /kaggle/input/input-key/training/training/Marina_Silva_21.jpg
# /kaggle/input/input-key/training/training/Flavia_Pennetta_31.jpg
# /kaggle/input/input-key/training/training/Roberto_Benigni_50.jpg
# /kaggle/input/input-key/training/training/Leuris_Pupo_22.jpg
# /kaggle/input/input-key/training/training/Richard_Paul_Evans_51.jpg
# /kaggle/input/input-key/training/training/Florecita_Cobian_00.jpg
# /kaggle/input/input-key/training/training/Carey_Lowell_22.jpg
# /kaggle/input/input-key/training/training/Marieta_Chrousala_01.jpg
# /kaggle/input/input-key/training/training/Fernando_Sanz_52.jpg
# /kaggle/input/input-key/training/training/Edie_Falco_31.jpg
# /kaggle/input/input-key/training/training/Ricardo_Sanchez_30.jpg
# /kaggle/input/input-key/training/training/Lindsey_Graham_32.jpg
# /kaggle/input/input-key/training/training/Tom_Coughlin_50.jpg
# /kaggle/input/input-key/training/training/Agbani_Darego_52.jpg
# /kaggle/input/input-key/training/training/Loretta_Lynn_Harper_02.jpg
# /kaggle/input/input-key/training/training/Christopher_Reeve_40.jpg
# /kaggle/input/input-key/training/training/Norah_Jones_40.jpg
# /kaggle/input/input-key/training/training/Louis_Van_Gaal_12.jpg
# /kaggle/input/input-key/training/training/Charlie_Coles_21.jpg
# /kaggle/input/input-key/training/training/Kate_Winslet_12.jpg
# /kaggle/input/input-key/training/training/Lucia_Kenny_Anthony_41.jpg
# /kaggle/input/input-key/training/training/Emma_Nicholson_30.jpg
# /kaggle/input/input-key/training/training/James_Cunningham_01.jpg
# /kaggle/input/input-key/training/training/Pilar_Montenegro_52.jpg
# /kaggle/input/input-key/training/training/Nina_Jacobson_00.jpg
# /kaggle/input/input-key/training/training/Penelope_Ann_Miller_01.jpg
# /kaggle/input/input-key/training/training/Reese_Witherspoon_10.jpg
# /kaggle/input/input-key/training/training/Gabi_Zimmer_50.jpg
# /kaggle/input/input-key/training/training/Nanni_Moretti_20.jpg
# /kaggle/input/input-key/training/training/Nancy_Reagan_00.jpg
# /kaggle/input/input-key/training/training/Chris_Cirino_31.jpg
# /kaggle/input/input-key/training/training/Ellen_DeGeneres_40.jpg
# /kaggle/input/input-key/training/training/Tessa_Jowell_30.jpg
# /kaggle/input/input-key/training/training/Pedro_Solbes_21.jpg
# /kaggle/input/input-key/training/training/Carlo_Azeglio_Ciampi_50.jpg
# /kaggle/input/input-key/training/training/Natasha_Lyonne_11.jpg
# /kaggle/input/input-key/training/training/Jaime_Pressly_12.jpg
# /kaggle/input/input-key/training/training/Cameron_Diaz_21.jpg
# /kaggle/input/input-key/training/training/Emile_Lahoud_32.jpg
# /kaggle/input/input-key/training/training/Jacqueline_Gold_21.jpg
# /kaggle/input/input-key/training/training/Lester_Holt_02.jpg
# /kaggle/input/input-key/training/training/Marc_Shaiman_12.jpg
# /kaggle/input/input-key/training/training/Rick_Bragg_50.jpg
# /kaggle/input/input-key/training/training/Louis_Van_Gaal_02.jpg
# /kaggle/input/input-key/training/training/Fidel_Castro_Daiz-Balart_12.jpg
# /kaggle/input/input-key/training/training/Sanjay_Gupta_10.jpg
# /kaggle/input/input-key/training/training/Marc_Racicot_21.jpg
# /kaggle/input/input-key/training/training/Agbani_Darego_41.jpg
# /kaggle/input/input-key/training/training/Janis_Ruth_Coulter_20.jpg
# /kaggle/input/input-key/training/training/James_Carville_12.jpg
# /kaggle/input/input-key/training/training/Loretta_Lynn_Harper_50.jpg
# /kaggle/input/input-key/training/training/Robert_Altman_20.jpg
# /kaggle/input/input-key/training/training/Dai_Bachtiar_11.jpg
# /kaggle/input/input-key/training/training/Gary_Coleman_41.jpg
# /kaggle/input/input-key/training/training/Sasha_Cohen_21.jpg
# /kaggle/input/input-key/training/training/Jake_Plummer_21.jpg
# /kaggle/input/input-key/training/training/Mahathir_Mohamad_22.jpg
# /kaggle/input/input-key/training/training/Emile_Lahoud_02.jpg
# /kaggle/input/input-key/training/training/Otto_Reich_32.jpg
# /kaggle/input/input-key/training/training/Barbara_Boxer_50.jpg
# /kaggle/input/input-key/training/training/Carlos_Iturgaitz_22.jpg
# /kaggle/input/input-key/training/training/William_Delahunt_22.jpg
# /kaggle/input/input-key/training/training/Kyle_Shewfelt_20.jpg
# /kaggle/input/input-key/training/training/Itzhak_Perlman_11.jpg
# /kaggle/input/input-key/training/training/Frank_Caliendo_30.jpg
# /kaggle/input/input-key/training/training/James_Cunningham_40.jpg
# /kaggle/input/input-key/training/training/Dai_Bachtiar_01.jpg
# /kaggle/input/input-key/training/training/Kieran_Culkin_21.jpg
# /kaggle/input/input-key/training/training/Princess_Stephanie_42.jpg
# /kaggle/input/input-key/training/training/Darrell_Issa_42.jpg
# /kaggle/input/input-key/training/training/Ernesto_Zedillo_21.jpg
# /kaggle/input/input-key/training/training/Bianca_Jagger_32.jpg
# /kaggle/input/input-key/training/training/Eliane_Karp_01.jpg
# /kaggle/input/input-key/training/training/Nina_Jacobson_32.jpg
# /kaggle/input/input-key/training/training/David_Caruso_01.jpg
# /kaggle/input/input-key/training/training/Kate_Winslet_02.jpg
# /kaggle/input/input-key/training/training/Ricardo_Sanchez_31.jpg
# /kaggle/input/input-key/training/training/Katja_Riemann_01.jpg
# /kaggle/input/input-key/training/training/Flavia_Pennetta_40.jpg
# /kaggle/input/input-key/training/training/Christopher_Amolsch_41.jpg
# /kaggle/input/input-key/training/training/Mario_Kreutzberger_30.jpg
# /kaggle/input/input-key/training/training/Sasha_Cohen_40.jpg
# /kaggle/input/input-key/training/training/Wesley_Clark_20.jpg
# /kaggle/input/input-key/training/training/Ahmad_Masood_30.jpg
# /kaggle/input/input-key/training/training/Chuck_Woolery_10.jpg
# /kaggle/input/input-key/training/training/Wayne_Newton_40.jpg
# /kaggle/input/input-key/training/training/Kristin_Chenoweth_52.jpg
# /kaggle/input/input-key/training/training/Bill_Bradley_31.jpg
# /kaggle/input/input-key/training/training/Geoffrey_Rush_01.jpg
# /kaggle/input/input-key/training/training/Whoopi_Goldberg_40.jpg
# /kaggle/input/input-key/training/training/Chris_Matthews_51.jpg
# /kaggle/input/input-key/training/training/Kate_Winslet_11.jpg
# /kaggle/input/input-key/training/training/Condoleezza_Rice_41.jpg
# /kaggle/input/input-key/training/training/Clive_Lloyd_42.jpg
# /kaggle/input/input-key/training/training/Eduardo_Duhalde_12.jpg
# /kaggle/input/input-key/training/training/Tina_Brown_50.jpg
# /kaggle/input/input-key/training/training/James_Hoffa_22.jpg
# /kaggle/input/input-key/training/training/George_Galloway_50.jpg
# /kaggle/input/input-key/training/training/Lucia_Kenny_Anthony_51.jpg
# /kaggle/input/input-key/training/training/Martin_Luther_King_III_00.jpg
# /kaggle/input/input-key/training/training/Elaine_Stritch_11.jpg
# /kaggle/input/input-key/training/training/Gary_Condit_30.jpg
# /kaggle/input/input-key/training/training/William_McDonough_30.jpg
# /kaggle/input/input-key/training/training/Nicolas_Eyzaguirre_10.jpg
# /kaggle/input/input-key/training/training/David_Caruso_10.jpg
# /kaggle/input/input-key/training/training/Thomas_Ferguson_01.jpg
# /kaggle/input/input-key/training/training/Katja_Riemann_00.jpg
# /kaggle/input/input-key/training/training/Elijah_Wood_00.jpg
# /kaggle/input/input-key/training/training/Chuck_Hagel_20.jpg
# /kaggle/input/input-key/training/training/Elsa_Zylberstein_10.jpg
# /kaggle/input/input-key/training/training/William_Delahunt_10.jpg
# /kaggle/input/input-key/training/training/Leuris_Pupo_20.jpg
# /kaggle/input/input-key/training/training/Carlos_Queiroz_12.jpg
# /kaggle/input/input-key/training/training/Angela_Bassett_22.jpg
# /kaggle/input/input-key/training/training/Nick_Reilly_11.jpg
# /kaggle/input/input-key/training/training/Christopher_Walken_41.jpg
# /kaggle/input/input-key/training/training/Gabi_Zimmer_21.jpg
# /kaggle/input/input-key/training/training/Claire_Danes_42.jpg
# /kaggle/input/input-key/training/training/Marc_Racicot_02.jpg
# /kaggle/input/input-key/training/training/Alex_Ferguson_50.jpg
# /kaggle/input/input-key/training/training/Aleksander_Kwasniewski_12.jpg
# /kaggle/input/input-key/training/training/Edward_Norton_50.jpg
# /kaggle/input/input-key/training/training/Philippe_Noiret_50.jpg
# /kaggle/input/input-key/training/training/Benedita_da_Silva_10.jpg
# /kaggle/input/input-key/training/training/Connie_Chung_42.jpg
# /kaggle/input/input-key/training/training/Loretta_Lynn_Harper_32.jpg
# /kaggle/input/input-key/training/training/Elizabeth_Dole_30.jpg
# /kaggle/input/input-key/training/training/Eric_Benet_10.jpg
# /kaggle/input/input-key/training/training/Linda_Dano_52.jpg
# /kaggle/input/input-key/training/training/Charlotte_Rampling_41.jpg
# /kaggle/input/input-key/training/training/Alma_Powell_42.jpg
# /kaggle/input/input-key/training/training/Dai_Bachtiar_00.jpg
# /kaggle/input/input-key/training/training/Princess_Stephanie_40.jpg
# /kaggle/input/input-key/training/training/Lee_Baca_40.jpg
# /kaggle/input/input-key/training/training/Edward_Burns_32.jpg
# /kaggle/input/input-key/training/training/Abdullah_Gul_52.jpg
# /kaggle/input/input-key/training/training/Bill_Frist_10.jpg
# /kaggle/input/input-key/training/training/Richard_Lennon_31.jpg
# /kaggle/input/input-key/training/training/Clark_Randt_51.jpg
# /kaggle/input/input-key/training/training/Ridley_Scott_20.jpg
# /kaggle/input/input-key/training/training/Kirk_Ferentz_52.jpg
# /kaggle/input/input-key/training/training/Kirk_Ferentz_42.jpg
# /kaggle/input/input-key/training/training/Warren_Beatty_32.jpg
# /kaggle/input/input-key/training/training/Liu_Ye_10.jpg
# /kaggle/input/input-key/training/training/Ted_Turner_22.jpg
# /kaggle/input/input-key/training/training/Tim_Pawlenty_42.jpg
# /kaggle/input/input-key/training/training/Zhong_Nanshan_00.jpg
# /kaggle/input/input-key/training/training/Charlize_Theron_50.jpg
# /kaggle/input/input-key/training/training/Jake_Plummer_51.jpg
# /kaggle/input/input-key/training/training/Charles_Bronson_02.jpg
# /kaggle/input/input-key/training/training/Erin_Hershey_Presley_31.jpg
# /kaggle/input/input-key/training/training/Tim_Howard_00.jpg
# /kaggle/input/input-key/training/training/Lyle_Lovett_20.jpg
# /kaggle/input/input-key/training/training/Tom_Sizemore_02.jpg
# /kaggle/input/input-key/training/training/Ben_Stein_31.jpg
# /kaggle/input/input-key/training/training/Emma_Thompson_21.jpg
# /kaggle/input/input-key/training/training/Chuck_Hagel_31.jpg
# /kaggle/input/input-key/training/training/Wesley_Clark_42.jpg
# /kaggle/input/input-key/training/training/Dan_Ackroyd_00.jpg
# /kaggle/input/input-key/training/training/Angel_Lockward_41.jpg
# /kaggle/input/input-key/training/training/Wayne_Newton_42.jpg
# /kaggle/input/input-key/training/training/Clay_Aiken_31.jpg
# /kaggle/input/input-key/training/training/Pat_Riley_52.jpg
# /kaggle/input/input-key/training/training/Beyonce_Knowles_52.jpg
# /kaggle/input/input-key/training/training/Mary_Robinson_50.jpg
# /kaggle/input/input-key/training/training/Emmy_Rossum_32.jpg
# /kaggle/input/input-key/training/training/Emilio_Botin_40.jpg
# /kaggle/input/input-key/training/training/Manuel_Pellegrini_10.jpg
# /kaggle/input/input-key/training/training/Aleksander_Kwasniewski_20.jpg
# /kaggle/input/input-key/training/training/Francis_Collins_42.jpg
# /kaggle/input/input-key/training/training/James_Cunningham_30.jpg
# /kaggle/input/input-key/training/training/Tom_Osborne_21.jpg
# /kaggle/input/input-key/training/training/Poala_Suarez_52.jpg
# /kaggle/input/input-key/training/training/Tom_Sizemore_11.jpg
# /kaggle/input/input-key/training/training/Carlo_Azeglio_Ciampi_21.jpg
# /kaggle/input/input-key/training/training/Lester_Holt_30.jpg
# /kaggle/input/input-key/training/training/Lucio_Stanca_42.jpg
# /kaggle/input/input-key/training/training/Louisa_Baileche_12.jpg
# /kaggle/input/input-key/training/training/Aishwarya_Rai_02.jpg
# /kaggle/input/input-key/training/training/Li_Zhaoxing_01.jpg
# /kaggle/input/input-key/training/training/Mariana_Ohata_21.jpg
# /kaggle/input/input-key/training/training/Itzhak_Perlman_40.jpg
# /kaggle/input/input-key/training/training/Erin_Hershey_Presley_32.jpg
# /kaggle/input/input-key/training/training/Paul_Reiser_21.jpg
# /kaggle/input/input-key/training/training/Catriona_Le_May_Doan_42.jpg
# /kaggle/input/input-key/training/training/Tessa_Jowell_21.jpg
# ...
# /kaggle/input/input-key/test/test/Emmy_Rossum_51.jpg
# /kaggle/input/input-key/test/test/Abdel_Aziz_Al-Hakim_40.jpg
# /kaggle/input/input-key/test/test/Barbara_Boxer_11.jpg
# /kaggle/input/input-key/test/test/Yuri_Fedotov_21.jpg
# /kaggle/input/input-key/test/test/Yuri_Fedotov_40.jpg
# /kaggle/input/input-key/test/test/Elaine_Chao_01.jpg
# /kaggle/input/input-key/test/test/Carlos_Iturgaitz_30.jpg
# /kaggle/input/input-key/test/test/Raja_Zafar-ul-Haq_31.jpg
# /kaggle/input/input-key/test/test/GL_Peiris_30.jpg
# /kaggle/input/input-key/test/test/Jane_Rooney_21.jpg
# /kaggle/input/input-key/test/test/Kristen_Breitweiser_00.jpg
# /kaggle/input/input-key/test/test/Luis_Fonsi_40.jpg
# /kaggle/input/input-key/test/test/Daniel_Rouse_11.jpg
# /kaggle/input/input-key/test/test/Marisa_Tomei_41.jpg
# /kaggle/input/input-key/test/test/Elizabeth_Shue_20.jpg
# /kaggle/input/input-key/test/test/Adam_Sandler_01.jpg
# /kaggle/input/input-key/test/test/Fernando_Sanz_40.jpg
# /kaggle/input/input-key/test/test/Wes_Craven_50.jpg
# /kaggle/input/input-key/test/test/Paul_Otellini_00.jpg
# /kaggle/input/input-key/test/test/Raza_Rabbani_50.jpg
# /kaggle/input/input-key/test/test/Mack_Brown_51.jpg
# /kaggle/input/input-key/test/test/Benjamin_McKenzie_41.jpg
# /kaggle/input/input-key/test/test/Nicolas_Sarkozy_20.jpg
# /kaggle/input/input-key/test/test/Lyle_Lovett_41.jpg
# /kaggle/input/input-key/test/test/Tina_Brown_51.jpg
# /kaggle/input/input-key/test/test/Angel_Lockward_51.jpg
# /kaggle/input/input-key/test/test/Ali_Abbas_50.jpg
# /kaggle/input/input-key/test/test/Queen_Rania_30.jpg
# /kaggle/input/input-key/test/test/Lucio_Stanca_00.jpg
# /kaggle/input/input-key/test/test/Valerie_Harper_50.jpg
# /kaggle/input/input-key/test/test/Cindy_Klassen_01.jpg
# /kaggle/input/input-key/test/test/Lincoln_Chafee_20.jpg
# /kaggle/input/input-key/test/test/Daisy_Fuentes_41.jpg
# /kaggle/input/input-key/test/test/Carey_Lowell_01.jpg
# /kaggle/input/input-key/test/test/Ellen_DeGeneres_50.jpg
# /kaggle/input/input-key/test/test/Abdel_Aziz_Al-Hakim_41.jpg
# /kaggle/input/input-key/test/test/Louisa_Baileche_00.jpg
# /kaggle/input/input-key/test/test/Kirsten_Dunst_30.jpg
# /kaggle/input/input-key/test/test/Keith_Olbermann_50.jpg
# /kaggle/input/input-key/test/test/Picabo_Street_40.jpg
# /kaggle/input/input-key/test/test/James_Lockhart_00.jpg
# /kaggle/input/input-key/test/test/Ahmad_Masood_41.jpg
# /kaggle/input/input-key/test/test/Queen_Noor_30.jpg
# /kaggle/input/input-key/test/test/Richard_Lennon_01.jpg
# /kaggle/input/input-key/test/test/Sanjay_Gupta_40.jpg
# /kaggle/input/input-key/test/test/Barry_Alvarez_31.jpg
# /kaggle/input/input-key/test/test/Peter_Medgyessy_31.jpg
# /kaggle/input/input-key/test/test/Maria_Soledad_Alvear_Valenzuela_11.jpg
# /kaggle/input/input-key/test/test/Frank_Caliendo_51.jpg
# /kaggle/input/input-key/test/test/Bianca_Jagger_30.jpg
# /kaggle/input/input-key/test/test/Sara_Silverman_41.jpg
# /kaggle/input/input-key/test/test/Jackie_Sherrill_50.jpg
# /kaggle/input/input-key/test/test/William_Donaldson_11.jpg
# /kaggle/input/input-key/test/test/Gary_Condit_01.jpg
# /kaggle/input/input-key/test/test/Emile_Lahoud_01.jpg
# /kaggle/input/input-key/test/test/David_Brent_10.jpg
# /kaggle/input/input-key/test/test/Charlize_Theron_51.jpg
# /kaggle/input/input-key/test/test/Katharine_Hepburn_40.jpg
# /kaggle/input/input-key/test/test/Clint_Howard_10.jpg
# /kaggle/input/input-key/test/test/Larry_Flynt_21.jpg
# /kaggle/input/input-key/test/test/Emilio_Botin_10.jpg
# /kaggle/input/input-key/test/test/Daniell_Sunjata_20.jpg
# /kaggle/input/input-key/test/test/Tom_Sizemore_01.jpg
# /kaggle/input/input-key/test/test/Peter_Goldmark_41.jpg
# /kaggle/input/input-key/test/test/T_Boone_Pickens_30.jpg
# /kaggle/input/input-key/test/test/George_Galloway_20.jpg
# /kaggle/input/input-key/test/test/Olene_Walker_10.jpg
# /kaggle/input/input-key/test/test/Larry_Flynt_00.jpg
# /kaggle/input/input-key/test/test/Carlos_Queiroz_01.jpg
# /kaggle/input/input-key/test/test/Pat_Riley_00.jpg
# /kaggle/input/input-key/test/test/Zhong_Nanshan_01.jpg
# /kaggle/input/input-key/test/test/Tina_Brown_21.jpg
# /kaggle/input/input-key/test/test/Estelle_Morris_21.jpg
# /kaggle/input/input-key/test/test/Charlie_Coles_01.jpg
# /kaggle/input/input-key/test/test/Ted_Turner_30.jpg
# /kaggle/input/input-key/test/test/Kieran_Culkin_10.jpg
# /kaggle/input/input-key/test/test/Luc_Montagnier_41.jpg
# /kaggle/input/input-key/test/test/Kristin_Chenoweth_40.jpg
# /kaggle/input/input-key/test/test/Nicolas_Eyzaguirre_20.jpg
# /kaggle/input/input-key/test/test/Queen_Rania_10.jpg
# /kaggle/input/input-key/test/test/Vojislav_Seselj_51.jpg
# /kaggle/input/input-key/test/test/Eliza_Dushku_31.jpg
# /kaggle/input/input-key/test/test/Tim_Howard_31.jpg
# /kaggle/input/input-key/test/test/Ernest_Hollings_01.jpg
# /kaggle/input/input-key/test/test/Emilio_Botin_01.jpg
# /kaggle/input/input-key/test/test/David_Brent_21.jpg
# /kaggle/input/input-key/test/test/Bill_Clinton_11.jpg
# /kaggle/input/input-key/test/test/Eliza_Dushku_20.jpg
# /kaggle/input/input-key/test/test/Valerie_Harper_41.jpg
# /kaggle/input/input-key/test/test/Gary_Condit_00.jpg
# /kaggle/input/input-key/test/test/George_Karl_10.jpg
# /kaggle/input/input-key/test/test/Jane_Krakowski_00.jpg
# /kaggle/input/input-key/test/test/Wayne_Gretzky_20.jpg
# /kaggle/input/input-key/test/test/Jane_Krakowski_10.jpg
# /kaggle/input/input-key/test/test/Alejandro_Toledo_31.jpg
# /kaggle/input/input-key/test/test/Nick_Reilly_51.jpg
# /kaggle/input/input-key/test/test/Lesia_Burlak_01.jpg
# /kaggle/input/input-key/test/test/Lino_Oviedo_01.jpg
# /kaggle/input/input-key/test/test/Mario_Kreutzberger_31.jpg
# /kaggle/input/input-key/test/test/Rick_Bragg_51.jpg
# /kaggle/input/input-key/test/test/Ellen_DeGeneres_10.jpg
# /kaggle/input/input-key/test/test/Carlo_Azeglio_Ciampi_11.jpg
# /kaggle/input/input-key/test/test/Richard_Paul_Evans_00.jpg
# /kaggle/input/input-key/test/test/Tom_Ridge_50.jpg
# /kaggle/input/input-key/test/test/Lyle_Lovett_21.jpg
# /kaggle/input/input-key/test/test/Kristen_Breitweiser_50.jpg
# /kaggle/input/input-key/test/test/Wayne_Gretzky_31.jpg
# /kaggle/input/input-key/test/test/Cecilia_Cheung_20.jpg
# /kaggle/input/input-key/test/test/Lindsey_Graham_10.jpg
# /kaggle/input/input-key/test/test/Barbara_Boxer_51.jpg
# /kaggle/input/input-key/test/test/Norman_Mineta_50.jpg
# /kaggle/input/input-key/test/test/Raja_Zafar-ul-Haq_01.jpg
# /kaggle/input/input-key/test/test/Isabelle_Huppert_30.jpg
# /kaggle/input/input-key/test/test/Matt_LeBlanc_20.jpg
# /kaggle/input/input-key/test/test/Lindsey_Graham_01.jpg
# /kaggle/input/input-key/test/test/Tom_Coughlin_21.jpg
# /kaggle/input/input-key/test/test/Barbara_Bodine_51.jpg
# /kaggle/input/input-key/test/test/James_Carville_31.jpg
# /kaggle/input/input-key/test/test/Charles_Bronson_50.jpg
# /kaggle/input/input-key/test/test/Rachel_Hunter_41.jpg
# /kaggle/input/input-key/test/test/Kathryn_Morris_21.jpg
# /kaggle/input/input-key/test/test/Eliza_Dushku_11.jpg
# /kaggle/input/input-key/test/test/Lester_Holt_00.jpg
# /kaggle/input/input-key/test/test/Picabo_Street_20.jpg
# /kaggle/input/input-key/test/test/Kate_Capshaw_20.jpg
# /kaggle/input/input-key/test/test/Thomas_Ferguson_51.jpg
# /kaggle/input/input-key/test/test/Angela_Bassett_40.jpg
# /kaggle/input/input-key/test/test/Matt_LeBlanc_01.jpg
# /kaggle/input/input-key/test/test/Yang_Jianli_11.jpg
# /kaggle/input/input-key/test/test/Kate_Capshaw_40.jpg
# /kaggle/input/input-key/test/test/Massoud_Barzani_01.jpg
# /kaggle/input/input-key/test/test/Thomas_Ferguson_11.jpg
# /kaggle/input/input-key/test/test/Beyonce_Knowles_00.jpg
# /kaggle/input/input-key/test/test/Jake_Gyllenhaal_00.jpg
# /kaggle/input/input-key/test/test/Carlo_Azeglio_Ciampi_20.jpg
# /kaggle/input/input-key/test/test/Benjamin_Netanyahu_10.jpg
# /kaggle/input/input-key/test/test/Eliza_Dushku_30.jpg
# /kaggle/input/input-key/test/test/Frank_Beamer_21.jpg
# /kaggle/input/input-key/test/test/Matt_LeBlanc_00.jpg
# /kaggle/input/input-key/test/test/Fidel_Castro_Daiz-Balart_11.jpg
# /kaggle/input/input-key/test/test/Queen_Rania_11.jpg
# /kaggle/input/input-key/test/test/Nicolas_Sarkozy_00.jpg
# /kaggle/input/input-key/test/test/Richard_Lugar_50.jpg
# /kaggle/input/input-key/test/test/Picabo_Street_01.jpg
# /kaggle/input/input-key/test/test/Ernesto_Zedillo_30.jpg
# /kaggle/input/input-key/test/test/Malcolm_Jamal_Warner_10.jpg
# /kaggle/input/input-key/test/test/Keith_Tyson_11.jpg
# /kaggle/input/input-key/test/test/Kevin_Satterfield_00.jpg
# /kaggle/input/input-key/test/test/Lindsey_Graham_20.jpg
# /kaggle/input/input-key/test/test/James_Lockhart_50.jpg
# /kaggle/input/input-key/test/test/Frances_Fisher_30.jpg
# /kaggle/input/input-key/test/test/Laurence_Fishburne_50.jpg
# /kaggle/input/input-key/test/test/Ellen_DeGeneres_41.jpg
# /kaggle/input/input-key/test/test/Barry_Alvarez_30.jpg
# /kaggle/input/input-key/test/test/Hassan_Nasrallah_51.jpg
# /kaggle/input/input-key/test/test/Agnes_Bruckner_01.jpg
# /kaggle/input/input-key/test/test/Richard_Paul_Evans_50.jpg
# /kaggle/input/input-key/test/test/Adrian_Nastase_10.jpg
# /kaggle/input/input-key/test/test/Martin_Sheen_30.jpg
# /kaggle/input/input-key/test/test/Aishwarya_Rai_00.jpg
# /kaggle/input/input-key/test/test/Richard_Lennon_00.jpg
# /kaggle/input/input-key/test/test/Chadha_Gurinder_50.jpg
# /kaggle/input/input-key/test/test/Ahmad_Masood_40.jpg
# /kaggle/input/input-key/test/test/Lee_Baca_11.jpg
# /kaggle/input/input-key/test/test/Estelle_Morris_30.jpg
# /kaggle/input/input-key/test/test/Matt_LeBlanc_21.jpg
# /kaggle/input/input-key/test/test/Mahathir_Mohamad_21.jpg
# /kaggle/input/input-key/test/test/Daisy_Fuentes_20.jpg
# /kaggle/input/input-key/test/test/George_Galloway_51.jpg
# /kaggle/input/input-key/test/test/Kristen_Breitweiser_11.jpg
# /kaggle/input/input-key/test/test/Aleksander_Kwasniewski_31.jpg
# /kaggle/input/input-key/test/test/Condoleezza_Rice_20.jpg
# /kaggle/input/input-key/test/test/Tom_Hanks_51.jpg
# /kaggle/input/input-key/test/test/Kathryn_Morris_10.jpg
# /kaggle/input/input-key/test/test/Clive_Lloyd_30.jpg
# /kaggle/input/input-key/test/test/Jackie_Sherrill_41.jpg
# /kaggle/input/input-key/test/test/Elijah_Wood_30.jpg
# /kaggle/input/input-key/test/test/Edward_Norton_11.jpg
# /kaggle/input/input-key/test/test/Barbara_Bodine_40.jpg
# /kaggle/input/input-key/test/test/Adrian_Nastase_51.jpg
# /kaggle/input/input-key/test/test/Penelope_Ann_Miller_00.jpg
# /kaggle/input/input-key/test/test/Condoleezza_Rice_30.jpg
# /kaggle/input/input-key/test/test/Luis_Fonsi_20.jpg
# /kaggle/input/input-key/test/test/Poala_Suarez_41.jpg
# /kaggle/input/input-key/test/test/Chris_Noth_11.jpg
# /kaggle/input/input-key/test/test/Loretta_Lynn_Harper_01.jpg
# /kaggle/input/input-key/test/test/Philippe_Gagnon_20.jpg
# /kaggle/input/input-key/test/test/Dan_Ackroyd_01.jpg
# /kaggle/input/input-key/test/test/Condoleezza_Rice_11.jpg
# /kaggle/input/input-key/test/test/Nick_Reilly_41.jpg
# /kaggle/input/input-key/test/test/Emile_Lahoud_41.jpg
# /kaggle/input/input-key/test/test/Jane_Rooney_10.jpg
# /kaggle/input/input-key/test/test/Marissa_Jaret_Winokur_01.jpg
# /kaggle/input/input-key/test/test/William_Delahunt_11.jpg
# /kaggle/input/input-key/test/test/Lester_Holt_31.jpg
# /kaggle/input/input-key/test/test/Jaime_Pressly_00.jpg
# /kaggle/input/input-key/test/test/Amelia_Vega_11.jpg
# /kaggle/input/input-key/test/test/Teresa_Heinz_Kerry_20.jpg
# /kaggle/input/input-key/test/test/Mahathir_Mohamad_30.jpg
# /kaggle/input/input-key/test/test/Pedro_Solbes_01.jpg
# /kaggle/input/input-key/test/test/Lincoln_Chafee_50.jpg
# /kaggle/input/input-key/test/test/Kristen_Breitweiser_51.jpg
# /kaggle/input/input-key/test/test/Cameron_Diaz_41.jpg
# /kaggle/input/input-key/test/test/Ethan_Hawke_41.jpg
# /kaggle/input/input-key/test/test/Paul_Reiser_20.jpg
# /kaggle/input/input-key/test/test/Clive_Lloyd_31.jpg
# /kaggle/input/input-key/test/test/Valerie_Harper_01.jpg
# /kaggle/input/input-key/test/test/Maggie_Cheung_51.jpg
# /kaggle/input/input-key/test/test/Recep_Tayyip_Erdogan_41.jpg
# /kaggle/input/input-key/test/test/Clark_Randt_20.jpg
# /kaggle/input/input-key/test/test/Otto_Reich_41.jpg
# /kaggle/input/input-key/test/test/Tom_Hanks_50.jpg
# /kaggle/input/input-key/test/test/Mahathir_Mohamad_11.jpg
# /kaggle/input/input-key/test/test/Benedita_da_Silva_20.jpg
# /kaggle/input/input-key/test/test/Gene_Hackman_21.jpg
# /kaggle/input/input-key/test/test/Biljana_Plavsic_30.jpg
# /kaggle/input/input-key/test/test/Albert_Brooks_00.jpg
# /kaggle/input/input-key/test/test/Dave_Campo_30.jpg
# /kaggle/input/input-key/test/test/Christine_Ebersole_20.jpg
# /kaggle/input/input-key/test/test/Flavia_Pennetta_50.jpg
# /kaggle/input/input-key/test/test/Gabi_Zimmer_00.jpg
# /kaggle/input/input-key/test/test/Ernest_Hollings_00.jpg
# /kaggle/input/input-key/test/test/Tim_Howard_30.jpg
# /kaggle/input/input-key/test/test/Charlie_Coles_11.jpg
# /kaggle/input/input-key/test/test/Ted_Turner_50.jpg
# /kaggle/input/input-key/test/test/Rocco_Buttiglione_00.jpg
# /kaggle/input/input-key/test/test/Eunice_Barber_51.jpg
# /kaggle/input/input-key/test/test/Eliane_Karp_40.jpg
# /kaggle/input/input-key/test/test/Sally_Ride_51.jpg
# /kaggle/input/input-key/test/test/Mark_Foley_10.jpg
# /kaggle/input/input-key/test/test/Carlos_Menem_31.jpg
# /kaggle/input/input-key/test/test/George_Karl_11.jpg
# /kaggle/input/input-key/test/test/Wes_Craven_20.jpg
# /kaggle/input/input-key/test/test/Carla_Gugino_30.jpg
# /kaggle/input/input-key/test/test/Danny_Glover_31.jpg
# /kaggle/input/input-key/test/test/Christopher_Amolsch_50.jpg
# /kaggle/input/input-key/test/test/Biljana_Plavsic_11.jpg
# /kaggle/input/input-key/test/test/Colin_Powell_40.jpg
# /kaggle/input/input-key/test/test/Carey_Lowell_31.jpg
# /kaggle/input/input-key/test/test/Florecita_Cobian_01.jpg
# /kaggle/input/input-key/test/test/Erin_Hershey_Presley_11.jpg
# /kaggle/input/input-key/test/test/Edward_Burns_11.jpg
# /kaggle/input/input-key/test/test/Natasha_Lyonne_41.jpg
# /kaggle/input/input-key/test/test/Claire_Danes_50.jpg
# /kaggle/input/input-key/test/test/Eliza_Dushku_00.jpg
# /kaggle/input/input-key/test/test/Sanjay_Gupta_20.jpg
# /kaggle/input/input-key/test/test/Chuck_Hagel_30.jpg
# /kaggle/input/input-key/test/test/Elmar_Brok_21.jpg
# /kaggle/input/input-key/test/test/Kirsten_Dunst_00.jpg
# /kaggle/input/input-key/test/test/Lesia_Burlak_00.jpg
# /kaggle/input/input-key/test/test/Charles_Bronson_51.jpg
# /kaggle/input/input-key/test/test/Laura_Bush_20.jpg
# /kaggle/input/input-key/test/test/Vojislav_Seselj_00.jpg
# /kaggle/input/input-key/test/test/Jacqueline_Gold_20.jpg
# /kaggle/input/input-key/test/test/Ernesto_Zedillo_31.jpg
# /kaggle/input/input-key/test/test/David_Caruso_11.jpg
# /kaggle/input/input-key/test/test/Timothy_Goebel_40.jpg
# /kaggle/input/input-key/test/test/Eliza_Dushku_01.jpg
# /kaggle/input/input-key/test/test/Aleksander_Kwasniewski_21.jpg
# /kaggle/input/input-key/test/test/Alvaro_Silva_Calderon_21.jpg
# /kaggle/input/input-key/test/test/Chris_Noth_10.jpg
# /kaggle/input/input-key/test/test/Jack_Welch_50.jpg
# /kaggle/input/input-key/test/test/Penelope_Ann_Miller_51.jpg
# /kaggle/input/input-key/test/test/Ellen_DeGeneres_11.jpg
# /kaggle/input/input-key/test/test/Maggie_Smith_31.jpg
# /kaggle/input/input-key/test/test/Nina_Jacobson_01.jpg
# /kaggle/input/input-key/test/test/Kieran_Culkin_01.jpg
# /kaggle/input/input-key/test/test/Emma_Thompson_30.jpg
# /kaggle/input/input-key/test/test/Natasha_Lyonne_40.jpg
# /kaggle/input/input-key/test/test/Alicia_Silverstone_00.jpg
# /kaggle/input/input-key/test/test/Pilar_Montenegro_11.jpg
# /kaggle/input/input-key/test/test/Itzhak_Perlman_10.jpg
# /kaggle/input/input-key/test/test/Richard_Paul_Evans_20.jpg
# /kaggle/input/input-key/test/test/Maggie_Smith_30.jpg
# /kaggle/input/input-key/test/test/Ben_Stein_51.jpg
# /kaggle/input/input-key/test/test/Luis_Fonsi_50.jpg
# /kaggle/input/input-key/test/test/Alfredo_di_Stefano_20.jpg
# /kaggle/input/input-key/test/test/Maria_Soledad_Alvear_Valenzuela_10.jpg
# /kaggle/input/input-key/test/test/Gene_Hackman_30.jpg
# /kaggle/input/input-key/test/test/Olivia_Newton-John_40.jpg
# /kaggle/input/input-key/test/test/Ricardo_Lopez_Murphy_31.jpg
# /kaggle/input/input-key/test/test/Harrison_Ford_21.jpg
# /kaggle/input/input-key/test/test/Raza_Rabbani_20.jpg
# /kaggle/input/input-key/test/test/Benedita_da_Silva_21.jpg
# /kaggle/input/input-key/test/test/Vicente_Fox_20.jpg
# /kaggle/input/input-key/test/test/Reese_Witherspoon_41.jpg
# /kaggle/input/custom-image/faces.jpg

# %%
#import the libraries
import glob
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import torch
import PIL

# %%
#loading the annotations file
key = pd.read_csv('../input/input-key/training_frames_keypoints.csv')
key.head()
# Out:
#                    Unnamed: 0     0     1     2      3     4      5     6  \
# 0           Luis_Fonsi_21.jpg  45.0  98.0  47.0  106.0  49.0  110.0  53.0
# 1       Lincoln_Chafee_52.jpg  41.0  83.0  43.0   91.0  45.0  100.0  47.0
# 2       Valerie_Harper_30.jpg  56.0  69.0  56.0   77.0  56.0   86.0  56.0
# 3         Angelo_Reyes_22.jpg  61.0  80.0  58.0   95.0  58.0  108.0  58.0
# 4  Kristen_Breitweiser_11.jpg  58.0  94.0  58.0  104.0  60.0  113.0  62.0
#
#        7     8  ...   126    127    128    129   130    131   132    133  \
# 0  119.0  56.0  ...  83.0  119.0   90.0  117.0  83.0  119.0  81.0  122.0
# 1  108.0  51.0  ...  85.0  122.0   94.0  120.0  85.0  122.0  83.0  122.0
# 2   94.0  58.0  ...  79.0  105.0   86.0  108.0  77.0  105.0  75.0  105.0
# 3  120.0  58.0  ...  98.0  136.0  107.0  139.0  95.0  139.0  91.0  139.0
# 4  121.0  67.0  ...  92.0  117.0  103.0  118.0  92.0  120.0  88.0  122.0
#
#     134    135
# 0  77.0  122.0
# 1  79.0  122.0
# 2  73.0  105.0
# 3  85.0  136.0
# 4  84.0  122.0
#
# [5 rows x 137 columns]

# %%
#UNCOMMENT BELOW COMMAND TO INSTALL imgaug lib
#!pip install imgaug
from imgaug import augmenters as iaa
import imgaug as ia

# %% [markdown]
# # DATA AUGMENTATION PIPELINE USING IMGAUG LIB FROM PYPI

# %%
class ImgAugTransform:
  def __init__(self):
    sometimes = lambda aug: iaa.Sometimes(0.5, aug)
    self.aug = iaa.Sequential([
        iaa.Sometimes(0.25, iaa.GaussianBlur(sigma=(0, 2.0))),#sigma was 3.0 initially
        iaa.Fliplr(0.4),# flip was 0.5 initially
        iaa.Affine(rotate=(-20, 20), mode='symmetric'),
        iaa.Sometimes(0.3,
                      iaa.OneOf([iaa.Dropout(p=(0, 0.1)), # in place of 0.3, 0.2 was placed
                                 iaa.CoarseDropout(0.1, size_percent=0.5)])),
        iaa.AddToHueAndSaturation(value=(-10, 10), per_channel=True),
         # Apply affine transformations to some of the images
        # - scale to 80-120% of image height/width (each axis independently)
        # - translate by -20 to +20 relative to height/width (per axis)
        # - rotate by -45 to +45 degrees
        # - shear by -16 to +16 degrees
        # - order: use nearest neighbour or bilinear interpolation (fast)
        # - mode: use any available mode to fill newly created pixels
        #         see API or scikit-image for which modes are available
        # - cval: if the mode is constant, then use a random brightness
        #         for the newly created pixels (e.g. sometimes black,
        #         sometimes white)
        sometimes(iaa.Affine(
            scale={"x": (0.8, 1.2), "y": (0.8, 1.2)},
            translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},
            rotate=(-45, 45),
            shear=(-16, 16),
            order=[0, 1],
            cval=(0, 255),
            mode=ia.ALL
        )),

        #
        # Execute 0 to 5 of the following (less important) augmenters per
        # image. Don't execute all of them, as that would often be way too
        # strong.
        #
        iaa.SomeOf((0, 5),
            [
                # Convert some images into their superpixel representation,
                # sample between 20 and 200 superpixels per image, but do
                # not replace all superpixels with their average, only
                # some of them (p_replace).
                sometimes(
                    iaa.Superpixels(
                        p_replace=(0, 1.0),
                        n_segments=(20, 200)
                    )
                ),

                # Blur each image with varying strength using
                # gaussian blur (sigma between 0 and 3.0),
                # average/uniform blur (kernel size between 2x2 and 7x7)
                # median blur (kernel size between 3x3 and 11x11).
                iaa.OneOf([
                    iaa.GaussianBlur((0, 3.0)),
                    iaa.AverageBlur(k=(2, 7)),
                    iaa.MedianBlur(k=(3, 11)),
                ]),

                # Sharpen each image, overlay the result with the original
                # image using an alpha between 0 (no sharpening) and 1
                # (full sharpening effect).
                iaa.Sharpen(alpha=(0, 1.0), lightness=(0.75, 1.5)),

                # Same as sharpen, but for an embossing effect.
                iaa.Emboss(alpha=(0, 1.0), strength=(0, 2.0)),

                # Search in some images either for all edges or for
                # directed edges. These edges are then marked in a black
                # and white image and overlayed with the original image
                # using an alpha of 0 to 0.7.
                sometimes(iaa.OneOf([
                    iaa.EdgeDetect(alpha=(0, 0.7)),
                    iaa.DirectedEdgeDetect(
                        alpha=(0, 0.7), direction=(0.0, 1.0)
                    ),
                ])),

                # Add gaussian noise to some images.
                # In 50% of these cases, the noise is randomly sampled per
                # channel and pixel.
                # In the other 50% of all cases it is sampled once per
                # pixel (i.e. brightness change).
                iaa.AdditiveGaussianNoise(
                    loc=0, scale=(0.0, 0.05*255), per_channel=0.5
                ),

                # Either drop randomly 1 to 10% of all pixels (i.e. set
                # them to black) or drop them on an image with 2-5% percent
                # of the original size, leading to large dropped
                # rectangles.
                iaa.OneOf([
                    iaa.Dropout((0.01, 0.1), per_channel=0.5),
                    iaa.CoarseDropout(
                        (0.03, 0.15), size_percent=(0.02, 0.05),
                        per_channel=0.2
                    ),
                ]),

                # Invert each image's channel with 5% probability.
                # This sets each pixel value v to 255-v.
                iaa.Invert(0.05, per_channel=True), # invert color channels

                # Add a value of -10 to 10 to each pixel.
                iaa.Add((-10, 10), per_channel=0.5),

                # Change brightness of images (50-150% of original value).
                iaa.Multiply((0.5, 1.5), per_channel=0.5),


                # Convert each image to grayscale and then overlay the
                # result with the original with random alpha. I.e. remove
                # colors with varying strengths.
                iaa.Grayscale(alpha=(0.0, 1.0)),

                # In some images move pixels locally around (with random
                # strengths).
                sometimes(
                    iaa.ElasticTransformation(alpha=(0.5, 3.5), sigma=0.25)
                ),

                # In some images distort local areas with varying strength.
                sometimes(iaa.PiecewiseAffine(scale=(0.01, 0.05)))
            ],
            # do all of the above augmentations in random order
            random_order=True
        )
    ],
    # do all of the above augmentations in random order
    random_order=True
)

    
      
  def __call__(self, sample):
    image, key_pts = sample['image'], sample['keypoints']
    img = np.array(image)
    return {'image': self.aug.augment_image(img), 'keypoints': key_pts}
    #return self.aug.augment_image(img)

# %%
class ToTensor(object):

    def __call__(self, sample):
        image, key_pts = sample['image'], sample['keypoints']
         
        # if image has no grayscale color channel, add one
        if(len(image.shape) == 2):
            # add that third color dim
            image = image.reshape(image.shape[0], image.shape[1], 3)
            
        # swap color axis because
        # numpy image: H x W x C
        # torch image: C X H X W
        image = image.transpose((2, 0, 1))
        
        return {'image': torch.from_numpy(image),
                'keypoints': torch.from_numpy(key_pts)}

#FUNCTION TO PERFORM NORMALIZATION
class Normalize(object):      

    def __call__(self, sample):
        image, key_pts = sample['image'], sample['keypoints']
        
        image_copy = np.copy(image)
        key_pts_copy = np.copy(key_pts)

        # convert image to grayscale
        #image_copy = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
        
        # scale color range from [0, 255] to [0, 1]
        image_copy=  image_copy/255.0
        #image_copy = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)
        # scale keypoints to be centered around 0 with a range of [-1, 1]
        # mean = 100, sqrt = 50, so, pts should be (pts - 100)/50
        key_pts_copy = (key_pts_copy - 100)/50.0


        return {'image': image_copy, 'keypoints': key_pts_copy}
    
#RESCALING FUNCTION    
class Rescale(object):
    

    def __init__(self, output_size):
        assert isinstance(output_size, (int, tuple))
        self.output_size = output_size

    def __call__(self, sample):
        image, key_pts = sample['image'], sample['keypoints']

        h, w = image.shape[:2]
        if isinstance(self.output_size, int):
            if h > w:
                new_h, new_w = self.output_size * h / w, self.output_size
            else:
                new_h, new_w = self.output_size, self.output_size * w / h
        else:
            new_h, new_w = self.output_size

        new_h, new_w = int(new_h), int(new_w)

        img = cv2.resize(image, (new_w, new_h))
        
        # scale the pts, too
        key_pts = key_pts * [new_w / w, new_h / h]

        return {'image': img, 'keypoints': key_pts}
    
    
#FUNCTION TO RANDOMLY CROP IMAGE 
class RandomCrop(object):

    def __init__(self, output_size):
        assert isinstance(output_size, (int, tuple))
        if isinstance(output_size, int):
            self.output_size = (output_size, output_size)
        else:
            assert len(output_size) == 2
            self.output_size = output_size

    def __call__(self, sample):
        image, key_pts = sample['image'], sample['keypoints']

        h, w = image.shape[:2]
        new_h, new_w = self.output_size

        top = np.random.randint(0, h - new_h)
        left = np.random.randint(0, w - new_w)

        image = image[top: top + new_h,
                      left: left + new_w]

        key_pts = key_pts - [left, top]

        return {'image': image, 'keypoints': key_pts}

# %% [markdown]
# # PROCESSING THE DATASET AND CONVERTING INTO A PROPER FORMAT
# ****MAKING DICTIONARY CONTAINING IMAGES WITH THIER KEYPOINTS IN (X,Y) FORM
# ****HERE X AND Y ARE THE CORDINATES OF A KEYPOINT

# %%
#ist column contain name of the file image and all other columns 
#contain the x and y axis of keypoints
#so we will separate them
#create a function to make a dataset of form A sample of our dataset will be a dictionary {'image': image, 'keypoints': key_pts}
from torch.utils.data import DataLoader , Dataset
from torchvision import transforms, utils

class facialdataset(Dataset):
    def __init__(self,csv_file , root_dir , transform  = None):
        self.key_csv = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform
    #function to return the length of keypoints dictionary
    def __len__(self):
        return len(self.key_csv)
    def __getitem__(self,idx):
        #append root dir and image name from csv to fetch image
        image_name = os.path.join(self.root_dir , self.key_csv.iloc[idx,0])
        image = mpimg.imread(image_name)
        #remove last channel if image have 4 channels instead of 3
        if image.shape[2] == 4:
            image = image[:,:,0:3]
        #now convert the cords in matrix and the reshape
        key_cords = self.key_csv.iloc[idx,1:].to_numpy()
        key_cords = key_cords.astype('float').reshape(-1,2)
        dictionary = {'image':image , 'keypoints':key_cords}
        
        #applying transform is not none:
        if self.transform:
            dictionary= self.transform(dictionary)
        return dictionary
# define the data tranform
# order matters! i.e. rescaling should come before a smaller crop
train_transforms = transforms.Compose([Rescale(250),
                                       ImgAugTransform(),#add the custom augmetations in the pytorch transform pipeline
                                        RandomCrop(224),
                                         Normalize(),
                                      ToTensor()])

# %% [markdown]
# # APPLY THE ABOVE DEFINED TRANSFORMATION ON THE DATASET
# HERE I AM USING A DATASET CONTAINING IMAGES OF FACES WITH THEIR RESPECTIVE KEYPOINTS AS (X,Y) FORM IN A CSV FILE

# %%
#after creating the class, we will pass the images and labels directory
#in the class to get the dictionary
face_dataset_train = facialdataset(csv_file='../input/input-key/training_frames_keypoints.csv',
                            root_dir='../input/input-key/training/training/',transform=train_transforms)
face_dataset_test = facialdataset(csv_file = '../input/input-key/test_frames_keypoints.csv',
                                 root_dir = '../input/input-key/test/test/',
                                 transform=train_transforms)

# %%
print('length of train data' , len(face_dataset_train))
print('length of test data' , len(face_dataset_test))
# Out:
# length of train data 3462
# length of test data 770

# %%
print("train" , face_dataset_train)
# Out:
# train <__main__.facialdataset object at 0x7f8f3ddf0790>

# %%
print('number of images in train' , len(face_dataset_train))
print('number of images in test' , len(face_dataset_test))
for i in range(1,5):
    sample = face_dataset_test[i]
    print(i , sample['image'].size() , sample['keypoints'].size() )
# Out:
# number of images in train 3462
# number of images in test 770
# 1 torch.Size([3, 224, 224]) torch.Size([68, 2])
# 2 torch.Size([3, 224, 224]) torch.Size([68, 2])
# 3 torch.Size([3, 224, 224]) torch.Size([68, 2])
# 4 torch.Size([3, 224, 224]) torch.Size([68, 2])

# %% [markdown]
# # ******BUILD MODEL AS PER THE TASK.
